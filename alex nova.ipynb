# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.api.types import is_string_dtype, is_numeric_dtype

df = pd.read_csv("/Users/alexshi/Downloads/winequality-red2.csv", header = 0)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df["quality"].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
import seaborn as sns
palette = sns.color_palette("Spectral")sns.heatmap(data=df.corr(),annot=True)
# Out:
#   Cell In[6], line 2
#     palette = sns.color_palette("Spectral")sns.heatmap(data=df.corr(),annot=True)
#                                            ^
# SyntaxError: invalid syntax

# %%
sns.pairplot(df, size=1.2, diag_kind = 'kde')
plt.show()
# Out:
# /Users/alexshi/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import numpy as np
corr = df.corr()
corr = corr[corr > 0.33] #getting the values that have more correlation 
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(25,20))
cmap = sns.diverging_palette(220, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, annot=True,square=True, linewidths=.5, cbar_kws={'shrink': .5})
plt.show()

# %%
df1 = df[['alcohol','citric acid', 'chlorides',
       'free sulfur dioxide', 'residual sugar', 'fixed acidity']]
df1
# Out:
#       alcohol  citric acid  chlorides  free sulfur dioxide  residual sugar  \
# 0         9.4         0.00      0.076                 11.0             1.9
# 1         9.8         0.00      0.098                 25.0             2.6
# 2         9.8         0.04      0.092                 15.0             2.3
# 3         9.8         0.56      0.075                 17.0             1.9
# 4         9.4         0.00      0.076                 11.0             1.9
# ...       ...          ...        ...                  ...             ...
# 1594     10.5         0.08      0.090                 32.0             2.0
# 1595     11.2         0.10      0.062                 39.0             2.2
# 1596     11.0         0.13      0.076                 29.0             2.3
# 1597     10.2         0.12      0.075                 32.0             2.0
# 1598     11.0         0.47      0.067                 18.0             3.6
#
#       fixed acidity
# 0               7.4
# 1               7.8
# ...

# %%
X = df[df.columns[0:]]
y = df[df.columns[-1]]

# %%
import warnings 
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest, SequentialFeatureSelector as sfs
from sklearn.datasets import load_wine

# %%
fs = SelectKBest(score_func=f_classif, k='all')
fs.fit(X, y)
X_train_fs = fs.transform(X)
X_test_fs = fs.transform(X)
for i in range(len(fs.scores_)):
    print(f'Feature {i}, Score {np.around(fs.scores_,2)[i]}')
# Out:
# Feature 0, Score 6.28
# Feature 1, Score 60.91
# Feature 2, Score 19.69
# Feature 3, Score 1.05
# Feature 4, Score 6.04
# Feature 5, Score 4.75
# Feature 6, Score 25.48
# Feature 7, Score 13.4
# Feature 8, Score 4.34
# Feature 9, Score 22.27
# Feature 10, Score 115.85
# Feature 11, Score inf

# %%
ANOVA_df =  pd.DataFrame()
ANOVA_df['Features'] = fs.feature_names_in_
ANOVA_df['Score'] =  fs.scores_
ANOVA_df.sort_values(by = 'Score' , ascending = True , inplace = True)
sns.barplot(x=ANOVA_df['Features'], y= ANOVA_df['Score'])
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.xticks(rotation=45)
plt.title("Independent Variable's p-values", fontsize=18)
plt.show()

# %%
>>> import numpy as np
>>> from sklearn.linear_model import LinearRegression

# %%
x = df['alcohol']
y = df['quality']
model = LinearRegression()

# %%
x
# Out:
# 0        9.4
# 1        9.8
# 2        9.8
# 3        9.8
# 4        9.4
#         ...
# 1594    10.5
# 1595    11.2
# 1596    11.0
# 1597    10.2
# 1598    11.0
# Name: alcohol, Length: 1599, dtype: float64

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

model = ols('quality ~ df["residual sugar"]', data=df).fit()
aov_table = sm.stats.anova_lm(model, typ=2)
aov_table
# Out:
#                            sum_sq      df         F    PR(>F)
# df["residual sugar"]     0.196508     1.0  0.301184  0.583218
# Residual              1041.968595  1597.0       NaN       NaN

# %%
sns.histplot(data=df["alcohol"])
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
oneway = ols('quality ~ C(alcohol)', data=df).fit()

# %%
model_resids = oneway.resid

# %%
model_norm_resids = oneway.get_influence().resid_studentized_internal
fitted = oneway.fittedvalues
sm.qqplot(model_norm_resids, line = '45')

# %%
import numpy as np
oneway = ols('quality ~ np.sqrt(df["alcohol"])', data=df).fit()

# %%
model_resids = oneway.resid

# %%
model_norm_resids = oneway.get_influence().resid_studentized_internal
fitted = oneway.fittedvalues
sm.qqplot(model_norm_resids, line = '45')

# %%
aov_table = sm.stats.anova_lm(oneway, typ=2)
aov_table
# Out:
#                             sum_sq      df           F        PR(>F)
# np.sqrt(df["alcohol"])  236.944323     1.0  469.933332  1.485035e-91
# Residual                805.220780  1597.0         NaN           NaN

# %%
model_resids = oneway.resid
